# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'C:\\Users\\marim\\Desktop\\summer 2024 projects\\internship 2024\\data\\datasets\\'

df = pd.read_csv(path+'Main_Dataset.csv')

# %%
df1 = pd.read_csv(path + 'Broken.csv')
df1 = df1.rename(columns={"Unnamed: 1": "correct"})

# %%
df1
# Out:
#       nodes   correct
# 0   N00-N01  2.692306
# 1   N00-N10  2.692306
# 2   N01-N02  1.538461
# 3   N01-N11  1.153846
# 4   N02-N03  0.769230
# 5   N02-N12  0.769230
# 6   N03-N13  0.769230
# 7   N10-N11  1.153846
# 8   N10-N20  1.538461
# 9   N11-N12  1.153846
# 10  N11-N21  1.153846
# 11  N12-N13  0.769230
# 12  N12-N22  1.153846
# 13  N13-N23  1.538461
# 14  N20-N21  0.769230
# 15  N20-N30  0.769230
# 16  N21-N22  1.153846
# 17  N21-N31  0.769230
# 18  N22-N23  1.153846
# 19  N22-N32  1.153846
# 20  N23-N33  2.692306
# 21  N30-N31  0.769230
# 22  N31-N32  1.538461
# 23  N32-N33  2.692306

# %%
df
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 0   2.692306  2.692306  1.538461  1.153846  0.769230  0.769230  0.769230
# 1   3.242556  2.387586  1.114630  0.000002  0.661811  0.452819  0.661811
# 2   2.838170  2.652871  1.890054  0.948116  0.506486  0.000001  0.506486
# 3   2.387586  3.242556  1.532615  0.854972  0.794806  0.737808  0.794806
# 4   2.741082  2.899602  1.155879  1.585203  0.726552  0.429327  0.726552
# 5   2.739344  2.751697  1.519456  1.219888  0.506486  1.012970  0.506486
# 6   2.899602  2.741082  1.472919  1.426683  0.726552  0.746367  0.726552
# 7   2.899602  2.741082  1.750329  1.149273  0.726552  1.023777  0.726552
# 8   2.652871  2.838170  1.519456  1.133415  0.765904  0.753551  0.765904
# 9   2.741082  2.899602  1.433289  1.307793  0.726552  0.706737  0.726552
# 10  2.786572  2.843570  1.532615  1.253957  0.661811  0.870804  0.661811
# 11  2.751697  2.739344  1.544162  1.207535  0.765904  0.778258  0.765904
# ...

# %%
# print(df.iloc[[6]])

# df = df.iloc[[6]]
# df

# %%
df1['zeros'] = 0.0
# df1['zeros'][2] = 1

df1.loc[1, 'zeros'] = 0.000002
df1.loc[2, 'zeros'] = 0.000001
df1.loc[3, 'zeros'] = 0.000002
df1.loc[4, 'zeros'] = 0.000002
df1.loc[5, 'zeros'] = 0.000002
df1.loc[6, 'zeros'] = 0.000002
df1.loc[7, 'zeros'] = 0.000002
df1.loc[8, 'zeros'] = 0.000002
df1.loc[9, 'zeros'] = 0.000002
df1.loc[10, 'zeros'] = 0.000002
df1.loc[11, 'zeros'] = 0.000001
df1.loc[12, 'zeros'] = 0.000002
df1
# Out:
#       nodes   correct     zeros
# 0   N00-N01  2.692306  0.000000
# 1   N00-N10  2.692306  0.000002
# 2   N01-N02  1.538461  0.000001
# 3   N01-N11  1.153846  0.000002
# 4   N02-N03  0.769230  0.000002
# 5   N02-N12  0.769230  0.000002
# 6   N03-N13  0.769230  0.000002
# 7   N10-N11  1.153846  0.000002
# 8   N10-N20  1.538461  0.000002
# 9   N11-N12  1.153846  0.000002
# 10  N11-N21  1.153846  0.000002
# 11  N12-N13  0.769230  0.000001
# 12  N12-N22  1.153846  0.000002
# 13  N13-N23  1.538461  0.000000
# 14  N20-N21  0.769230  0.000000
# 15  N20-N30  0.769230  0.000000
# 16  N21-N22  1.153846  0.000000
# 17  N21-N31  0.769230  0.000000
# 18  N22-N23  1.153846  0.000000
# 19  N22-N32  1.153846  0.000000
# 20  N23-N33  2.692306  0.000000
# 21  N30-N31  0.769230  0.000000
# 22  N31-N32  1.538461  0.000000
# 23  N32-N33  2.692306  0.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nodes    24 non-null     object
#  1   correct  24 non-null     float64
#  2   zeros    24 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 708.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   N00-N01  13 non-null     float64
#  1   N00-N10  13 non-null     float64
#  2   N01-N02  13 non-null     float64
#  3   N01-N11  13 non-null     float64
#  4   N02-N03  13 non-null     float64
#  5   N02-N12  13 non-null     float64
#  6   N03-N13  13 non-null     float64
#  7   N10-N11  13 non-null     float64
#  8   N10-N20  13 non-null     float64
#  9   N11-N12  13 non-null     float64
#  10  N11-N21  13 non-null     float64
#  11  N12-N13  13 non-null     float64
#  12  N12-N22  13 non-null     float64
#  13  N13-N23  13 non-null     float64
#  14  N20-N21  13 non-null     float64
#  15  N20-N30  13 non-null     float64
#  16  N21-N22  13 non-null     float64
#  17  N21-N31  13 non-null     float64
#  18  N22-N23  13 non-null     float64
#  19  N22-N32  13 non-null     float64
# ...

# %%
df.describe()
# Out:
#          N00-N01    N00-N10    N01-N02    N01-N11    N02-N03    N02-N12  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    2.785849   2.785849   1.511575   1.110588   0.702573   0.702573
# std     0.189937   0.189937   0.206758   0.381057   0.096610   0.273356
# min     2.387586   2.387586   1.114630   0.000002   0.506486   0.000001
# 25%     2.739344   2.739344   1.472919   1.133415   0.661811   0.706737
# 50%     2.751697   2.751697   1.532615   1.196959   0.726552   0.753551
# 75%     2.843570   2.843570   1.544162   1.253957   0.765904   0.851804
# max     3.242556   3.242556   1.890054   1.585203   0.794806   1.023777
#
#          N03-N13    N10-N11    N10-N20    N11-N12  ...    N20-N30    N21-N22  \
# count  13.000000  13.000000  13.000000  13.000000  ...  13.000000  13.000000
# mean    0.702573   1.110588   1.511575   1.103560  ...   0.702573   1.103560
# std     0.096610   0.381057   0.206758   0.417069  ...   0.096610   0.417069
# ...

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
row = df.columns.tolist()
row.pop()
row.pop()
row
# Out:
# ['N00-N01',
#  'N00-N10',
#  'N01-N02',
#  'N01-N11',
#  'N02-N03',
#  'N02-N12',
#  'N03-N13',
#  'N10-N11',
#  'N10-N20',
#  'N11-N12',
#  'N11-N21',
#  'N12-N13',
#  'N12-N22',
#  'N13-N23',
#  'N20-N21',
#  'N20-N30',
#  'N21-N22',
#  'N21-N31',
#  'N22-N23',
#  'N22-N32',
#  'N23-N33',
#  'N30-N31',
#  'N31-N32',
#  'N32-N33']

# %%
import numpy as np
X = df[row]
y = df1["zeros"].iloc[0:13]

# %%
X
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 0   2.692306  2.692306  1.538461  1.153846  0.769230  0.769230  0.769230
# 1   3.242556  2.387586  1.114630  0.000002  0.661811  0.452819  0.661811
# 2   2.838170  2.652871  1.890054  0.948116  0.506486  0.000001  0.506486
# 3   2.387586  3.242556  1.532615  0.854972  0.794806  0.737808  0.794806
# 4   2.741082  2.899602  1.155879  1.585203  0.726552  0.429327  0.726552
# 5   2.739344  2.751697  1.519456  1.219888  0.506486  1.012970  0.506486
# 6   2.899602  2.741082  1.472919  1.426683  0.726552  0.746367  0.726552
# 7   2.899602  2.741082  1.750329  1.149273  0.726552  1.023777  0.726552
# 8   2.652871  2.838170  1.519456  1.133415  0.765904  0.753551  0.765904
# 9   2.741082  2.899602  1.433289  1.307793  0.726552  0.706737  0.726552
# 10  2.786572  2.843570  1.532615  1.253957  0.661811  0.870804  0.661811
# 11  2.751697  2.739344  1.544162  1.207535  0.765904  0.778258  0.765904
# ...

# %%
y.iloc[0:13]
# Out:
# 0     0.000000
# 1     0.000002
# 2     0.000001
# 3     0.000002
# 4     0.000002
# 5     0.000002
# 6     0.000002
# 7     0.000002
# 8     0.000002
# 9     0.000002
# 10    0.000002
# 11    0.000001
# 12    0.000002
# Name: zeros, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,  random_state = 42)

# %%
X_train
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 5   2.739344  2.751697  1.519456  1.219888  0.506486  1.012970  0.506486
# 2   2.838170  2.652871  1.890054  0.948116  0.506486  0.000001  0.506486
# 1   3.242556  2.387586  1.114630  0.000002  0.661811  0.452819  0.661811
# 12  2.843570  2.786572  1.646611  1.196959  0.794806  0.851804  0.794806
# 4   2.741082  2.899602  1.155879  1.585203  0.726552  0.429327  0.726552
# 7   2.899602  2.741082  1.750329  1.149273  0.726552  1.023777  0.726552
# 10  2.786572  2.843570  1.532615  1.253957  0.661811  0.870804  0.661811
# 3   2.387586  3.242556  1.532615  0.854972  0.794806  0.737808  0.794806
# 6   2.899602  2.741082  1.472919  1.426683  0.726552  0.746367  0.726552
#
#      N10-N11   N10-N20   N11-N12  ...   N20-N21   N20-N30   N21-N22   N21-N31  \
# 5   1.207535  1.544162  1.312538  ...  0.778258  0.765904  1.139592  0.753551
# 2   1.133415  1.519456  0.941939  ...  0.753551  0.765904  1.114885  0.778258
# ...

# %%
X_test
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 11  2.751697  2.739344  1.544162  1.207535  0.765904  0.778258  0.765904
# 9   2.741082  2.899602  1.433289  1.307793  0.726552  0.706737  0.726552
# 0   2.692306  2.692306  1.538461  1.153846  0.769230  0.769230  0.769230
# 8   2.652871  2.838170  1.519456  1.133415  0.765904  0.753551  0.765904
#
#      N10-N11   N10-N20   N11-N12  ...   N20-N21   N20-N30   N21-N22   N21-N31  \
# 11  1.219888  1.519456  1.114885  ...  1.012970  0.506486  0.941939  0.000001
# 9   1.149273  1.750329  0.832233  ...  1.023777  0.726552  0.000002  0.429327
# 0   1.153846  1.538461  1.153846  ...  0.769230  0.769230  1.153846  0.769230
# 8   0.948116  1.890054  1.139592  ...  0.000001  0.506486  1.312538  1.012970
#
#      N22-N23   N22-N32   N23-N33   N30-N31   N31-N32   N32-N33
# 11  1.133415  0.948116  2.652871  0.506486  1.890054  2.838170
# 9   1.426683  1.585203  2.899602  0.726552  1.155879  2.741082
# ...

# %%
y_train
# Out:
# 5     0.000002
# 2     0.000001
# 1     0.000002
# 12    0.000002
# 4     0.000002
# 7     0.000002
# 10    0.000002
# 3     0.000002
# 6     0.000002
# Name: zeros, dtype: float64

# %%
y_test
# Out:
# 11    0.000001
# 9     0.000002
# 0     0.000000
# 8     0.000002
# Name: zeros, dtype: float64

# %%
#training the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 8.70540981e-08,  7.16335887e-08, -7.35086375e-07, -6.30272166e-08,
#         2.82746415e-07,  6.48330606e-07,  2.80975316e-07, -7.46852750e-08,
#        -6.09524164e-08, -5.93320805e-08, -7.39882934e-08, -8.98949266e-08,
#        -4.38761022e-08, -2.77727991e-08, -3.41379464e-08, -2.89469804e-08,
#        -5.81356266e-08, -3.88917895e-08, -6.80857353e-08, -3.83181110e-08,
#         1.02336872e-07, -2.76363473e-08, -8.79039068e-08,  1.27945357e-07])

# %%
cdf = pd.DataFrame(lm.coef_, X.columns, columns = ['Coef'])
print(cdf)
# Out:
#                  Coef
# N00-N01  8.705410e-08
# N00-N10  7.163359e-08
# N01-N02 -7.350864e-07
# N01-N11 -6.302722e-08
# N02-N03  2.827464e-07
# N02-N12  6.483306e-07
# N03-N13  2.809753e-07
# N10-N11 -7.468527e-08
# N10-N20 -6.095242e-08
# N11-N12 -5.933208e-08
# N11-N21 -7.398829e-08
# N12-N13 -8.989493e-08
# N12-N22 -4.387610e-08
# N13-N23 -2.777280e-08
# N20-N21 -3.413795e-08
# N20-N30 -2.894698e-08
# N21-N22 -5.813563e-08
# N21-N31 -3.889179e-08
# N22-N23 -6.808574e-08
# N22-N32 -3.831811e-08
# N23-N33  1.023369e-07
# N30-N31 -2.763635e-08
# N31-N32 -8.790391e-08
# N32-N33  1.279454e-07

# %%
#predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([1.92255904e-06, 2.00000000e-06, 1.88648071e-06, 1.93791500e-06])

# %%
y_test
# Out:
# 11    0.000001
# 9     0.000002
# 0     0.000000
# 8     0.000002
# Name: zeros, dtype: float64

# %%
# sns.scatterplot(predictions, y_test)
sns.scatterplot(x=predictions,y=y_test)
plt.xlabel("Predictions")
# Out:
# Text(0.5, 0, 'Predictions')
