# %%
import pandas as pd

# %%
path = 'C:\\Users\\marim\\Desktop\\summer 2024 projects\\internship 2024\\data\\datasets\\'

# %%
def reshape_df(br):
    df = pd.DataFrame()
    df = pd.read_csv(path+'Broken_VDLoc'+br+'.csv')
    # print(df)
    num_pairs = len(df) # for this instance it will be 12
    reshaped_data = df.values.reshape(-1, num_pairs * 2) #3
    # print(reshaped_data)
    reshaped_df = pd.DataFrame(reshaped_data, columns=column_names)
    return reshaped_df

# %%
df = reshape_df('')

# %%
# df = pd.read_csv(path + 'Broken_VDLoc.csv')
# # df = df.rename(columns={"Unnamed: 1": "correct"})

# df
# Out:
#     location   voltage
# 0        100  2.692306
# 1        200  2.692306
# 2        101  1.538461
# 3        102  0.769230
# 4        203  0.769230
# 5        210  1.538461
# 6        213  1.538461
# 7        220  0.769230
# 8        223  2.692306
# 9        130  0.769230
# 10       131  1.538461
# 11       132  2.692306

# %%
for i in br:
    # print(i)
    # df_new = pd.read_csv(path + 'Broken'+ i + '.csv') # read from csv FileExistsError
    df_new = reshape_df(i)
    print(df_new)
    # df = pd.merge(df, df_new, on="nodes")
    df = pd.concat([df, df_new], axis=0, ignore_index=True)

df
# Out:
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   3.242556    2.0   2.387586   1.01    1.11463   1.02   0.661811
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.661811  ...    2.2   0.794806   2.23   2.786572     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.794806    1.31    1.646611    1.32     2.84357
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0    2.83817    2.0   2.652871   1.01   1.890054   1.02   0.506486
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.506486  ...    2.2   0.765904   2.23   2.739344     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.765904    1.31    1.544162    1.32    2.751697
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.387586    2.0   3.242556   1.01   1.532615   1.02   0.794806
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.794806  ...    2.2   0.661811   2.23    2.84357     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.661811    1.31    1.532615    1.32    2.786572
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.741082    2.0   2.899602   1.01   1.155879   1.02   0.726552
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.726552  ...    2.2   0.726552   2.23   2.899602     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.726552    1.31    1.433289    1.32    2.741082
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.899602    2.0   2.741082   1.01   1.472919   1.02   0.726552
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.726552  ...    2.2   0.726552   2.23   2.741082     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.726552    1.31    1.750329    1.32    2.899602
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.739344    2.0   2.751697   1.01   1.519456   1.02   0.506486
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.506486  ...    2.2   0.765904   2.23    2.83817     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.765904    1.31    1.519456    1.32    2.652871
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.899602    2.0   2.741082   1.01   1.750329   1.02   0.726552
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.726552  ...    2.2   0.726552   2.23   2.741082     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.726552    1.31    1.472919    1.32    2.899602
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.652871    2.0    2.83817   1.01   1.519456   1.02   0.765904
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.765904  ...    2.2   0.506486   2.23   2.751697     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.506486    1.31    1.519456    1.32    2.739344
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.741082    2.0   2.899602   1.01   1.433289   1.02   0.726552
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.726552  ...    2.2   0.726552   2.23   2.899602     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.726552    1.31    1.155879    1.32    2.741082
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.751697    2.0   2.739344   1.01   1.544162   1.02   0.765904
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.765904  ...    2.2   0.506486   2.23   2.652871     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.506486    1.31    1.890054    1.32     2.83817
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0    1.0   2.786572    2.0    2.84357   1.01   1.532615   1.02   0.661811
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0   2.03   0.661811  ...    2.2   0.794806   2.23   3.242556     1.3
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.794806    1.31    1.532615    1.32    2.387586
#
# [1 rows x 24 columns]
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 
# 11    0.794806    1.31    1.532615    1.32    2.387586
# 12    0.661811    1.31    1.114630    1.32    3.242556
#
# [13 rows x 24 columns]

# %%
broken = 'V01'
df = pd.read_csv(path+'Broken_VDLoc'+broken+'.csv')
df
# Out:
#     location   voltage
# 0        100  3.242556
# 1        200  2.387586
# 2        101  1.114630
# 3        102  0.661811
# 4        203  0.661811
# 5        210  1.532615
# 6        213  1.532615
# 7        220  0.794806
# 8        223  2.786572
# 9        130  0.794806
# 10       131  1.646611
# 11       132  2.843570

# %%
num_pairs = len(df)

print(num_pairs)
# Out:
# 12

# %%
reshaped_data = df.values.reshape(-1, num_pairs * 2) #3
print(reshaped_data)
# Out:
# [[100.           3.24255574 200.           2.3875863  101.
#     1.11462967 102.           0.6618111  203.           0.6618111
#   210.           1.53261473 213.           1.53261473 220.
#     0.79480635 223.           2.78657204 130.           0.79480635
#   131.           1.64661065 132.           2.84357   ]]

# %%
column_names = []
for i in range(num_pairs):
    # column_names.append(f'VD_{i+1}')
    column_names.append(f'Loc_{i+1}')
    column_names.append(f'voltage_{i+1}')

column_names
# Out:
# ['Loc_1',
#  'voltage_1',
#  'Loc_2',
#  'voltage_2',
#  'Loc_3',
#  'voltage_3',
#  'Loc_4',
#  'voltage_4',
#  'Loc_5',
#  'voltage_5',
#  'Loc_6',
#  'voltage_6',
#  'Loc_7',
#  'voltage_7',
#  'Loc_8',
#  'voltage_8',
#  'Loc_9',
#  'voltage_9',
#  'Loc_10',
#  'voltage_10',
#  'Loc_11',
#  'voltage_11',
#  'Loc_12',
#  'voltage_12']

# %%
reshaped_df = pd.DataFrame(reshaped_data, columns=column_names)

reshaped_df
# Out:
#    Loc_1  voltage_1  Loc_2  voltage_2  Loc_3  voltage_3  Loc_4  voltage_4  \
# 0  100.0   3.242556  200.0   2.387586  101.0    1.11463  102.0   0.661811
#
#    Loc_5  voltage_5  ...  Loc_8  voltage_8  Loc_9  voltage_9  Loc_10  \
# 0  203.0   0.661811  ...  220.0   0.794806  223.0   2.786572   130.0
#
#    voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0    0.794806   131.0    1.646611   132.0     2.84357
#
# [1 rows x 24 columns]

# %%
broken = pd.read_csv(path+'Broken_dataset.csv')
broken
# Out:
#    resistor  location
# 0       V01      2.01
# 1       V02      2.02
# 2       H10      1.10
# 3       H11      1.11
# 4       V11      2.11
# 5       H12      1.12
# 6       V12      2.12
# 7       H20      1.20
# 8       H21      1.21
# 9       V21      2.21
# 10      H22      1.22
# 11      V22      2.22

# %%
# br = ['V01', 'V02', 'H10', 'H11', 'H12', 'V11', 'V12', 'H20', 'H21', 'H22', 'V21', 'V22'] 
br = broken['resistor']
# br = ['101', '102', '210', '211', '212', '111', '112', '220', '221', '222', '121', '122'] 
br
# Out:
# 0     V01
# 1     V02
# 2     H10
# 3     H11
# 4     V11
# 5     H12
# 6     V12
# 7     H20
# 8     H21
# 9     V21
# 10    H22
# 11    V22
# Name: resistor, dtype: object

# %%
df
# Out:
#     Loc_1  voltage_1  Loc_2  voltage_2   Loc_3  voltage_3   Loc_4  voltage_4  \
# 0   100.0   2.692306  200.0   2.692306  101.00   1.538461  102.00   0.769230
# 1     1.0   3.242556    2.0   2.387586    1.01   1.114630    1.02   0.661811
# 2     1.0   2.838170    2.0   2.652871    1.01   1.890054    1.02   0.506486
# 3     1.0   2.387586    2.0   3.242556    1.01   1.532615    1.02   0.794806
# 4     1.0   2.741082    2.0   2.899602    1.01   1.155879    1.02   0.726552
# 5     1.0   2.899602    2.0   2.741082    1.01   1.472919    1.02   0.726552
# 6     1.0   2.739344    2.0   2.751697    1.01   1.519456    1.02   0.506486
# 7     1.0   2.899602    2.0   2.741082    1.01   1.750329    1.02   0.726552
# 8     1.0   2.652871    2.0   2.838170    1.01   1.519456    1.02   0.765904
# 9     1.0   2.741082    2.0   2.899602    1.01   1.433289    1.02   0.726552
# 10    1.0   2.751697    2.0   2.739344    1.01   1.544162    1.02   0.765904
# 11    1.0   2.786572    2.0   2.843570    1.01   1.532615    1.02   0.661811
# 12    1.0   2.843570    2.0   2.786572    1.01   1.646611    1.02   0.794806
#
#      Loc_5  voltage_5  ...  Loc_8  voltage_8   Loc_9  voltage_9  Loc_10  \
# 0   203.00   0.769230  ...  220.0   0.769230  223.00   2.692306   130.0
# 1     2.03   0.661811  ...    2.2   0.794806    2.23   2.786572     1.3
# 2     2.03   0.506486  ...    2.2   0.765904    2.23   2.739344     1.3
# 3     2.03   0.794806  ...    2.2   0.661811    2.23   2.843570     1.3
# 4     2.03   0.726552  ...    2.2   0.726552    2.23   2.899602     1.3
# 5     2.03   0.726552  ...    2.2   0.726552    2.23   2.741082     1.3
# 6     2.03   0.506486  ...    2.2   0.765904    2.23   2.838170     1.3
# 7     2.03   0.726552  ...    2.2   0.726552    2.23   2.741082     1.3
# 8     2.03   0.765904  ...    2.2   0.506486    2.23   2.751697     1.3
# 9     2.03   0.726552  ...    2.2   0.726552    2.23   2.899602     1.3
# 10    2.03   0.765904  ...    2.2   0.506486    2.23   2.652871     1.3
# 11    2.03   0.661811  ...    2.2   0.794806    2.23   3.242556     1.3
# 12    2.03   0.794806  ...    2.2   0.661811    2.23   2.387586     1.3
#
#     voltage_10  Loc_11  voltage_11  Loc_12  voltage_12
# 0     0.769230  131.00    1.538461  132.00    2.692306
# 1     0.794806    1.31    1.646611    1.32    2.843570
# 2     0.765904    1.31    1.544162    1.32    2.751697
# 3     0.661811    1.31    1.532615    1.32    2.786572
# 4     0.726552    1.31    1.433289    1.32    2.741082
# 5     0.726552    1.31    1.750329    1.32    2.899602
# 6     0.765904    1.31    1.519456    1.32    2.652871
# 7     0.726552    1.31    1.472919    1.32    2.899602
# 8     0.506486    1.31    1.519456    1.32    2.739344
# 9     0.726552    1.31    1.155879    1.32    2.741082
# 10    0.506486    1.31    1.890054    1.32    2.838170
# 11    0.794806    1.31    1.532615    1.32    2.387586
# 12    0.661811    1.31    1.114630    1.32    3.242556
#
# [13 rows x 24 columns]

# %%
df.to_csv(path+'VDLoc.csv', index=False)
