# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'C:\\Users\\marim\\Desktop\\summer 2024 projects\\internship 2024\\data\\datasets\\'

df = pd.read_csv(path+'Main_Dataset.csv')

# %%
df1 = pd.read_csv(path + 'Correct_Dataset.csv')

# %%
df1
# Out:
#     N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 0  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
#
#     N10-N11   N10-N20   N11-N12  ...  N20-N30   N21-N22  N21-N31   N22-N23  \
# 0  1.153846  1.538461  1.153846  ...  0.76923  1.153846  0.76923  1.153846
#
#     N22-N32   N23-N33  N30-N31   N31-N32   N32-N33    nodes
# 0  1.153846  2.692306  0.76923  1.538461  2.692306  correct
#
# [1 rows x 25 columns]

# %%
col = df1.columns
col[:24]
# Out:
# Index(['N00-N01', 'N00-N10', 'N01-N02', 'N01-N11', 'N02-N03', 'N02-N12',
#        'N03-N13', 'N10-N11', 'N10-N20', 'N11-N12', 'N11-N21', 'N12-N13',
#        'N12-N22', 'N13-N23', 'N20-N21', 'N20-N30', 'N21-N22', 'N21-N31',
#        'N22-N23', 'N22-N32', 'N23-N33', 'N30-N31', 'N31-N32', 'N32-N33'],
#       dtype='object')

# %%
repeated_values = np.repeat(df1.values, 13, axis=0)

df1 = pd.DataFrame(repeated_values, columns=df1.columns)

df1
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 0   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 1   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 2   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 3   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 4   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 5   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 6   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 7   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 8   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 9   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 10  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 11  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# ...

# %%
df1.loc[1, 'N01-N11'] = 0.0
df1.loc[2, 'N02-N12'] = 0.0
df1.loc[3, 'N10-N11'] = 0.0
df1.loc[4, 'N11-N12'] = 0.0
df1.loc[5, 'N12-N13'] = 0.0
df1.loc[6, 'N11-N21'] = 0.0
df1.loc[7, 'N12-N22'] = 0.0
df1.loc[8, 'N20-N21'] = 0.0
df1.loc[9, 'N21-N22'] = 0.0
df1.loc[10, 'N22-N23'] = 0.0
df1.loc[11, 'N21-N31'] = 0.0
df1.loc[12, 'N22-N32'] = 0.0

df.loc[1, 'N01-N11'] = 0.0
df.loc[2, 'N02-N12'] = 0.0
df.loc[3, 'N10-N11'] = 0.0
df.loc[4, 'N11-N12'] = 0.0
df.loc[5, 'N12-N13'] = 0.0
df.loc[6, 'N11-N21'] = 0.0
df.loc[7, 'N12-N22'] = 0.0
df.loc[8, 'N20-N21'] = 0.0
df.loc[9, 'N21-N22'] = 0.0
df.loc[10, 'N22-N23'] = 0.0
df.loc[11, 'N21-N31'] = 0.0
df.loc[12, 'N22-N32'] = 0.0

df1
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 0   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 1   2.692306  2.692306  1.538461       0.0  0.76923  0.76923  0.76923
# 2   2.692306  2.692306  1.538461  1.153846  0.76923      0.0  0.76923
# 3   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 4   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 5   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 6   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 7   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 8   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 9   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 10  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 11  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# ...

# %%
df.head()
# Out:
#     N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 0  2.692306  2.692306  1.538461  1.153846  0.769230  0.769230  0.769230
# 1  3.242556  2.387586  1.114630  0.000000  0.661811  0.452819  0.661811
# 2  2.838170  2.652871  1.890054  0.948116  0.506486  0.000000  0.506486
# 3  2.387586  3.242556  1.532615  0.854972  0.794806  0.737808  0.794806
# 4  2.741082  2.899602  1.155879  1.585203  0.726552  0.429327  0.726552
#
#     N10-N11   N10-N20   N11-N12  ...   N21-N22   N21-N31   N22-N23   N22-N32  \
# 0  1.153846  1.538461  1.153846  ...  1.153846  0.769230  1.153846  1.153846
# 1  0.854972  1.532615  1.567446  ...  1.301456  0.851804  1.253957  1.196959
# 2  1.133415  1.519456  0.941939  ...  1.114885  0.778258  1.219888  1.207535
# 3  0.000000  1.114630  1.415452  ...  1.149461  0.870804  1.196959  1.253957
# 4  1.426683  1.472919  0.000000  ...  0.832233  0.706737  1.149273  1.307793
#
#     N23-N33   N30-N31   N31-N32   N32-N33    nodes  numbers
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   N00-N01  13 non-null     float64
#  1   N00-N10  13 non-null     float64
#  2   N01-N02  13 non-null     float64
#  3   N01-N11  13 non-null     float64
#  4   N02-N03  13 non-null     float64
#  5   N02-N12  13 non-null     float64
#  6   N03-N13  13 non-null     float64
#  7   N10-N11  13 non-null     float64
#  8   N10-N20  13 non-null     float64
#  9   N11-N12  13 non-null     float64
#  10  N11-N21  13 non-null     float64
#  11  N12-N13  13 non-null     float64
#  12  N12-N22  13 non-null     float64
#  13  N13-N23  13 non-null     float64
#  14  N20-N21  13 non-null     float64
#  15  N20-N30  13 non-null     float64
#  16  N21-N22  13 non-null     float64
#  17  N21-N31  13 non-null     float64
#  18  N22-N23  13 non-null     float64
#  19  N22-N32  13 non-null     float64
# ...

# %%
df.describe()
# Out:
#          N00-N01    N00-N10    N01-N02    N01-N11    N02-N03    N02-N12  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    2.785849   2.785849   1.511575   1.110588   0.702573   0.702573
# std     0.189937   0.189937   0.206758   0.381057   0.096610   0.273357
# min     2.387586   2.387586   1.114630   0.000000   0.506486   0.000000
# 25%     2.739344   2.739344   1.472919   1.133415   0.661811   0.706737
# 50%     2.751697   2.751697   1.532615   1.196959   0.726552   0.753551
# 75%     2.843570   2.843570   1.544162   1.253957   0.765904   0.851804
# max     3.242556   3.242556   1.890054   1.585203   0.794806   1.023777
#
#          N03-N13    N10-N11    N10-N20    N11-N12  ...    N20-N30    N21-N22  \
# count  13.000000  13.000000  13.000000  13.000000  ...  13.000000  13.000000
# mean    0.702573   1.110588   1.511575   1.103560  ...   0.702573   1.103560
# std     0.096610   0.381057   0.206758   0.417070  ...   0.096610   0.417070
# ...

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
row = df.columns.tolist()
row.pop()
row.pop()
row
# Out:
# ['N00-N01',
#  'N00-N10',
#  'N01-N02',
#  'N01-N11',
#  'N02-N03',
#  'N02-N12',
#  'N03-N13',
#  'N10-N11',
#  'N10-N20',
#  'N11-N12',
#  'N11-N21',
#  'N12-N13',
#  'N12-N22',
#  'N13-N23',
#  'N20-N21',
#  'N20-N30',
#  'N21-N22',
#  'N21-N31',
#  'N22-N23',
#  'N22-N32',
#  'N23-N33',
#  'N30-N31',
#  'N31-N32',
#  'N32-N33']

# %%
X = df[row]
y = df1[row]

# %%
X
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 0   2.692306  2.692306  1.538461  1.153846  0.769230  0.769230  0.769230
# 1   3.242556  2.387586  1.114630  0.000000  0.661811  0.452819  0.661811
# 2   2.838170  2.652871  1.890054  0.948116  0.506486  0.000000  0.506486
# 3   2.387586  3.242556  1.532615  0.854972  0.794806  0.737808  0.794806
# 4   2.741082  2.899602  1.155879  1.585203  0.726552  0.429327  0.726552
# 5   2.739344  2.751697  1.519456  1.219888  0.506486  1.012970  0.506486
# 6   2.899602  2.741082  1.472919  1.426683  0.726552  0.746367  0.726552
# 7   2.899602  2.741082  1.750329  1.149273  0.726552  1.023777  0.726552
# 8   2.652871  2.838170  1.519456  1.133415  0.765904  0.753551  0.765904
# 9   2.741082  2.899602  1.433289  1.307793  0.726552  0.706737  0.726552
# 10  2.786572  2.843570  1.532615  1.253957  0.661811  0.870804  0.661811
# 11  2.751697  2.739344  1.544162  1.207535  0.765904  0.778258  0.765904
# ...

# %%
y
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 0   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 1   2.692306  2.692306  1.538461       0.0  0.76923  0.76923  0.76923
# 2   2.692306  2.692306  1.538461  1.153846  0.76923      0.0  0.76923
# 3   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 4   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 5   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 6   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 7   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 8   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 9   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 10  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 11  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5, random_state = 42)

# %%
X_train
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 12  2.843570  2.786572  1.646611  1.196959  0.794806  0.851804  0.794806
# 4   2.741082  2.899602  1.155879  1.585203  0.726552  0.429327  0.726552
# 7   2.899602  2.741082  1.750329  1.149273  0.726552  1.023777  0.726552
# 10  2.786572  2.843570  1.532615  1.253957  0.661811  0.870804  0.661811
# 3   2.387586  3.242556  1.532615  0.854972  0.794806  0.737808  0.794806
# 6   2.899602  2.741082  1.472919  1.426683  0.726552  0.746367  0.726552
#
#      N10-N11   N10-N20   N11-N12  ...   N20-N21   N20-N30   N21-N22   N21-N31  \
# 12  1.253957  1.532615  1.301456  ...  0.870804  0.661811  1.567446  0.452819
# 4   1.426683  1.472919  0.000000  ...  0.746367  0.726552  0.832233  0.706737
# 7   1.307793  1.433289  1.624833  ...  0.706737  0.726552  0.792603  0.746367
# 10  1.196959  1.646611  1.149461  ...  0.851804  0.794806  1.415452  0.737808
# ...

# %%
X_test
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 11  2.751697  2.739344  1.544162  1.207535  0.765904  0.778258  0.765904
# 9   2.741082  2.899602  1.433289  1.307793  0.726552  0.706737  0.726552
# 0   2.692306  2.692306  1.538461  1.153846  0.769230  0.769230  0.769230
# 8   2.652871  2.838170  1.519456  1.133415  0.765904  0.753551  0.765904
# 5   2.739344  2.751697  1.519456  1.219888  0.506486  1.012970  0.506486
# 2   2.838170  2.652871  1.890054  0.948116  0.506486  0.000000  0.506486
# 1   3.242556  2.387586  1.114630  0.000000  0.661811  0.452819  0.661811
#
#      N10-N11   N10-N20   N11-N12  ...   N20-N21   N20-N30   N21-N22   N21-N31  \
# 11  1.219888  1.519456  1.114885  ...  1.012970  0.506486  0.941939  0.000000
# 9   1.149273  1.750329  0.832233  ...  1.023777  0.726552  0.000000  0.429327
# 0   1.153846  1.538461  1.153846  ...  0.769230  0.769230  1.153846  0.769230
# ...

# %%
y_train
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 12  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 4   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 7   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 10  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 3   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 6   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
#
#      N10-N11   N10-N20   N11-N12  ...  N20-N21  N20-N30   N21-N22  N21-N31  \
# 12  1.153846  1.538461  1.153846  ...  0.76923  0.76923  1.153846  0.76923
# 4   1.153846  1.538461       0.0  ...  0.76923  0.76923  1.153846  0.76923
# 7   1.153846  1.538461  1.153846  ...  0.76923  0.76923  1.153846  0.76923
# 10  1.153846  1.538461  1.153846  ...  0.76923  0.76923  1.153846  0.76923
# 3        0.0  1.538461  1.153846  ...  0.76923  0.76923  1.153846  0.76923
# ...

# %%
y_test
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 11  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 9   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 0   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 8   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 5   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 2   2.692306  2.692306  1.538461  1.153846  0.76923      0.0  0.76923
# 1   2.692306  2.692306  1.538461       0.0  0.76923  0.76923  0.76923
#
#      N10-N11   N10-N20   N11-N12  ...  N20-N21  N20-N30   N21-N22  N21-N31  \
# 11  1.153846  1.538461  1.153846  ...  0.76923  0.76923  1.153846      0.0
# 9   1.153846  1.538461  1.153846  ...  0.76923  0.76923       0.0  0.76923
# 0   1.153846  1.538461  1.153846  ...  0.76923  0.76923  1.153846  0.76923
# 8   1.153846  1.538461  1.153846  ...      0.0  0.76923  1.153846  0.76923
# ...

# %%
#training the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
# ...

# %%
cdf = pd.DataFrame(lm.coef_, X.columns)

print(cdf)
# Out:
#                0         1         2         3         4         5         6   \
# N00-N01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# N00-N10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# N01-N02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# N01-N11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# N02-N03  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# N02-N12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# N03-N13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# N10-N11  0.145616 -0.150989  0.010696  0.145270 -0.024624  0.035120 -0.029615
# N10-N20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# N11-N12 -0.091807 -0.029930  0.145780 -0.067104  0.012228  0.130269 -0.069987
# N11-N21  0.021010  0.006642 -0.003471 -0.015080 -0.002739  0.000029  0.016340
# ...

# %%
#predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([[2.69230624e+00, 2.69230624e+00, 1.53846071e+00, 1.15384553e+00,
#         7.69230355e-01, 7.69230355e-01, 7.69230355e-01, 1.09409889e+00,
#         1.53846071e+00, 7.06591606e-01, 1.51022830e+00, 7.69230355e-01,
#         6.72858503e-01, 1.53846071e+00, 7.69230355e-01, 7.69230355e-01,
#         1.15384553e+00, 7.69230355e-01, 1.05846213e+00, 7.26922439e-01,
#         2.69230624e+00, 7.69230355e-01, 1.53846071e+00, 2.69230624e+00],
#        [2.69230624e+00, 2.69230624e+00, 1.53846071e+00, 1.15384553e+00,
#         7.69230355e-01, 7.69230355e-01, 7.69230355e-01, 1.15384554e+00,
#         1.53846071e+00, 7.47415864e-08, 2.30769105e+00, 7.69230355e-01,
#         1.71145584e-08, 1.53846071e+00, 7.69230355e-01, 7.69230355e-01,
#         1.15384553e+00, 7.69230355e-01, 1.15384553e+00, 1.15384545e+00,
#         2.69230624e+00, 7.69230355e-01, 1.53846071e+00, 2.69230624e+00],
#        [2.69230624e+00, 2.69230624e+00, 1.53846071e+00, 1.15384553e+00,
# ...

# %%
pre = pd.DataFrame(predictions, columns = col[:24])
print(pre)
# Out:
#     N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 0  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 1  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 2  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 3  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 4  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 5  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 6  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
#
#     N10-N11   N10-N20       N11-N12  ...  N20-N21  N20-N30   N21-N22  N21-N31  \
# 0  1.094099  1.538461  7.065916e-01  ...  0.76923  0.76923  1.153846  0.76923
# 1  1.153846  1.538461  7.474159e-08  ...  0.76923  0.76923  1.153846  0.76923
# 2  0.936140  1.538461  8.111736e-01  ...  0.76923  0.76923  1.153846  0.76923
# 3  0.715300  1.538461  1.005534e+00  ...  0.76923  0.76923  1.153846  0.76923
# ...

# %%
print(y_test)
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 11  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 9   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 0   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 8   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 5   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 2   2.692306  2.692306  1.538461  1.153846  0.76923      0.0  0.76923
# 1   2.692306  2.692306  1.538461       0.0  0.76923  0.76923  0.76923
#
#      N10-N11   N10-N20   N11-N12  ...  N20-N21  N20-N30   N21-N22  N21-N31  \
# 11  1.153846  1.538461  1.153846  ...  0.76923  0.76923  1.153846      0.0
# 9   1.153846  1.538461  1.153846  ...  0.76923  0.76923       0.0  0.76923
# 0   1.153846  1.538461  1.153846  ...  0.76923  0.76923  1.153846  0.76923
# 8   1.153846  1.538461  1.153846  ...      0.0  0.76923  1.153846  0.76923
# ...

# %%
X_test
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11   N02-N03   N02-N12   N03-N13  \
# 11  2.751697  2.739344  1.544162  1.207535  0.765904  0.778258  0.765904
# 9   2.741082  2.899602  1.433289  1.307793  0.726552  0.706737  0.726552
# 0   2.692306  2.692306  1.538461  1.153846  0.769230  0.769230  0.769230
# 8   2.652871  2.838170  1.519456  1.133415  0.765904  0.753551  0.765904
# 5   2.739344  2.751697  1.519456  1.219888  0.506486  1.012970  0.506486
# 2   2.838170  2.652871  1.890054  0.948116  0.506486  0.000000  0.506486
# 1   3.242556  2.387586  1.114630  0.000000  0.661811  0.452819  0.661811
#
#      N10-N11   N10-N20   N11-N12  ...   N20-N21   N20-N30   N21-N22   N21-N31  \
# 11  1.219888  1.519456  1.114885  ...  1.012970  0.506486  0.941939  0.000000
# 9   1.149273  1.750329  0.832233  ...  1.023777  0.726552  0.000000  0.429327
# 0   1.153846  1.538461  1.153846  ...  0.769230  0.769230  1.153846  0.769230
# ...

# %%
r = y_test.index
r
# Out:
# Index([11, 9, 0, 8, 5, 2, 1], dtype='int64')

# %%
pre.index = r 
pre
# Out:
#      N00-N01   N00-N10   N01-N02   N01-N11  N02-N03  N02-N12  N03-N13  \
# 11  2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 9   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 0   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 8   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 5   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 2   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
# 1   2.692306  2.692306  1.538461  1.153846  0.76923  0.76923  0.76923
#
#      N10-N11   N10-N20       N11-N12  ...  N20-N21  N20-N30   N21-N22  \
# 11  1.094099  1.538461  7.065916e-01  ...  0.76923  0.76923  1.153846
# 9   1.153846  1.538461  7.474159e-08  ...  0.76923  0.76923  1.153846
# 0   0.936140  1.538461  8.111736e-01  ...  0.76923  0.76923  1.153846
# 8   0.715300  1.538461  1.005534e+00  ...  0.76923  0.76923  1.153846
# ...

# %%
# Initialize lists to store the locations of differences
differences = []

# Iterate over rows and columns
for row in range(pre.shape[0]):  # Iterate over rows
    for col in range(pre.shape[1]):  # Iterate over columns
        # Compare values in df1 and df2
        if pre.iat[row, col] != y_test.iat[row, col]:
            differences.append((row, col, pre.iat[row, col], y_test.iat[row, col]))

# Print locations of differing values
for row, col, val1, val2 in differences:
    print(f"Difference at row {row}, column {df1.columns[col]}: df1 has {val1}, df2 has {val2}")
# Out:
# Difference at row 0, column N10-N11: df1 has 1.0940988883132705, df2 has 1.153845532544711
# Difference at row 0, column N11-N12: df1 has 0.7065916061335644, df2 has 1.1538455325447128
# Difference at row 0, column N11-N21: df1 has 1.5102283012017244, df2 has 1.1538455325447128
# Difference at row 0, column N12-N22: df1 has 0.6728585033130846, df2 has 1.1538455325447137
# Difference at row 0, column N21-N31: df1 has 0.7692303550298094, df2 has 0.0
# Difference at row 0, column N22-N23: df1 has 1.0584621286877154, df2 has 1.1538455325447146
# Difference at row 0, column N22-N32: df1 has 0.7269224386294564, df2 has 1.1538455325447146
# Difference at row 1, column N10-N11: df1 has 1.1538455373472458, df2 has 1.153845532544711
# Difference at row 1, column N11-N12: df1 has 7.474158641995743e-08, df2 has 1.1538455325447128
# Difference at row 1, column N11-N21: df1 has 2.3076910475738046, df2 has 1.1538455325447128
# ...
