# %% [raw]
# Cleaning data

# %%
import pandas as pd

# %%
path = 'C:\\Users\\marim\\Desktop\\summer 2024 projects\\internship 2024\\data\\'

df= pd.read_csv(path + "correct.csv") # read from csv FileExistsError
df
# Out:
#    node1 node2   voltage1  voltage2
# 0    N00   N01  10.000000  7.307694
# 1    N00   N10  10.000000  7.307694
# 2    N01   N02   7.307694  5.769233
# 3    N01   N11   7.307694  6.153848
# 4    N02   N03   5.769233  5.000003
# 5    N02   N12   5.769233  5.000003
# 6    N03   N13   5.000003  4.230772
# 7    N10   N11   7.307694  6.153848
# 8    N10   N20   7.307694  5.769233
# 9    N11   N12   6.153848  5.000003
# 10   N11   N21   6.153848  5.000003
# 11   N12   N13   5.000003  4.230772
# 12   N12   N22   5.000003  3.846157
# 13   N13   N23   4.230772  2.692312
# 14   N20   N21   5.769233  5.000003
# 15   N20   N30   5.769233  5.000003
# 16   N21   N22   5.000003  3.846157
# 17   N21   N31   5.000003  4.230772
# 18   N22   N23   3.846157  2.692312
# 19   N22   N32   3.846157  2.692312
# 20   N23   N33   2.692312  0.000005
# 21   N30   N31   5.000003  4.230772
# 22   N31   N32   4.230772  2.692312
# 23   N32   N33   2.692312  0.000005

# %%
n = 5
def loop(ib,ie,ir,jb,je,jr):
    for i in range(ib, ie, ir):
        for j in range(jb, je, jr):
            print(i, j)
loop(0, 1, 1, 0, n-1, 1) # top line
print()
loop(0, n-1, 1, n-1, n, 1) # right line
print()
loop(n-1, n, 1, n-1, 0, -1) # bottom line
print()
loop(n-1, 0, -1, 0, 1, 1) # right line
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
#
# 0 4
# 1 4
# 2 4
# 3 4
#
# 4 4
# 4 3
# 4 2
# 4 1
#
# 4 0
# 3 0
# 2 0
# 1 0

# %%
def node_name(i, j):
    return f'N{i}{j}'

# %%
n = 4
ch = 'A'

data = []
def loop(ib,ie,ir,jb,je,jr):
    global ch
    for i in range(ib, ie, ir):
        for j in range(jb, je, jr):
            node = node_name(i, j)
            print('Node {}: {}'.format(node, ch))
            data.append([node, node, ch, ch])
            ch = chr(ord(ch) + 1)
            
loop(0, 1, 1, 0, n-1, 1) # top line
print()
loop(0, n-1, 1, n-1, n, 1) # right line
print()
loop(n-1, n, 1, n-1, 0, -1) # bottom line
print()
loop(n-1, 0, -1, 0, 1, 1) # right line

df_right = pd.DataFrame(data, columns=['node1', 'node2', 'letters1', 'letters2'])
# Out:
# Node N00: A
# Node N01: B
# Node N02: C
#
# Node N03: D
# Node N13: E
# Node N23: F
#
# Node N33: G
# Node N32: H
# Node N31: I
#
# Node N30: J
# Node N20: K
# Node N10: L

# %%
df_right
# Out:
#    node1 node2 letters1 letters2
# 0    N00   N00        A        A
# 1    N01   N01        B        B
# 2    N02   N02        C        C
# 3    N03   N03        D        D
# 4    N13   N13        E        E
# 5    N23   N23        F        F
# 6    N33   N33        G        G
# 7    N32   N32        H        H
# 8    N31   N31        I        I
# 9    N30   N30        J        J
# 10   N20   N20        K        K
# 11   N10   N10        L        L

# %%
df
# Out:
#    node1 node2   voltage1  voltage2
# 0    N00   N01  10.000000  7.307694
# 1    N00   N10  10.000000  7.307694
# 2    N01   N02   7.307694  5.769233
# 3    N01   N11   7.307694  6.153848
# 4    N02   N03   5.769233  5.000003
# 5    N02   N12   5.769233  5.000003
# 6    N03   N13   5.000003  4.230772
# 7    N10   N11   7.307694  6.153848
# 8    N10   N20   7.307694  5.769233
# 9    N11   N12   6.153848  5.000003
# 10   N11   N21   6.153848  5.000003
# 11   N12   N13   5.000003  4.230772
# 12   N12   N22   5.000003  3.846157
# 13   N13   N23   4.230772  2.692312
# 14   N20   N21   5.769233  5.000003
# 15   N20   N30   5.769233  5.000003
# 16   N21   N22   5.000003  3.846157
# 17   N21   N31   5.000003  4.230772
# 18   N22   N23   3.846157  2.692312
# 19   N22   N32   3.846157  2.692312
# 20   N23   N33   2.692312  0.000005
# 21   N30   N31   5.000003  4.230772
# 22   N31   N32   4.230772  2.692312
# 23   N32   N33   2.692312  0.000005

# %%
result = pd.merge(df, df_right, how="outer", on=["node1", "node2"])
result
# Out:
#    node1 node2   voltage1  voltage2 letters1 letters2
# 0    N00   N00        NaN       NaN        A        A
# 1    N00   N01  10.000000  7.307694      NaN      NaN
# 2    N00   N10  10.000000  7.307694      NaN      NaN
# 3    N01   N01        NaN       NaN        B        B
# 4    N01   N02   7.307694  5.769233      NaN      NaN
# 5    N01   N11   7.307694  6.153848      NaN      NaN
# 6    N02   N02        NaN       NaN        C        C
# 7    N02   N03   5.769233  5.000003      NaN      NaN
# 8    N02   N12   5.769233  5.000003      NaN      NaN
# 9    N03   N03        NaN       NaN        D        D
# 10   N03   N13   5.000003  4.230772      NaN      NaN
# 11   N10   N10        NaN       NaN        L        L
# 12   N10   N11   7.307694  6.153848      NaN      NaN
# 13   N10   N20   7.307694  5.769233      NaN      NaN
# 14   N11   N12   6.153848  5.000003      NaN      NaN
# 15   N11   N21   6.153848  5.000003      NaN      NaN
# ...

# %%
result = pd.merge(df, df_right, how="outer", on="node1")
result
# Out:
#    node1 node2_x   voltage1  voltage2 node2_y letters1 letters2
# 0    N00     N01  10.000000  7.307694     N00        A        A
# 1    N00     N10  10.000000  7.307694     N00        A        A
# 2    N01     N02   7.307694  5.769233     N01        B        B
# 3    N01     N11   7.307694  6.153848     N01        B        B
# 4    N02     N03   5.769233  5.000003     N02        C        C
# 5    N02     N12   5.769233  5.000003     N02        C        C
# 6    N03     N13   5.000003  4.230772     N03        D        D
# 7    N10     N11   7.307694  6.153848     N10        L        L
# 8    N10     N20   7.307694  5.769233     N10        L        L
# 9    N11     N12   6.153848  5.000003     NaN      NaN      NaN
# 10   N11     N21   6.153848  5.000003     NaN      NaN      NaN
# 11   N12     N13   5.000003  4.230772     NaN      NaN      NaN
# 12   N12     N22   5.000003  3.846157     NaN      NaN      NaN
# 13   N13     N23   4.230772  2.692312     N13        E        E
# ...

# %%
n = 4
ch = 'A'

#df.loc[(df['ID1']==900000498)&(df['ID2']==900022133), 'Proximity']
#print(df1.loc[(900000498,900022133), 'Proximity'])

data = []
def loop_(ib,ie,ir,jb,je,jr):
    global ch
    for i in range(ib, ie, ir):
        for j in range(jb, je, jr):
            node = node_name(i, j)
            print('Node {}: {}'.format(node, ch))
            data.append([node, ch])
            ch = chr(ord(ch) + 1)
            
loop(0, 1, 1, 0, n-1, 1) # top line
print()
loop(0, n-1, 1, n-1, n, 1) # right line
print()
loop(n-1, n, 1, n-1, 0, -1) # bottom line
print()
loop(n-1, 0, -1, 0, 1, 1) # right line

df_right = pd.DataFrame(data, columns=['node1', 'letters'])
# Out:
# Node N00: A
# Node N01: B
# Node N02: C
#
# Node N03: D
# Node N13: E
# Node N23: F
#
# Node N33: G
# Node N32: H
# Node N31: I
#
# Node N30: J
# Node N20: K
# Node N10: L
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# ...
