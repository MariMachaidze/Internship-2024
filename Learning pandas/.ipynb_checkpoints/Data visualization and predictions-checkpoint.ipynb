# %%
import pandas as pd

# %%
path = 'C:\\Users\\marim\\Desktop\\summer 2024 projects\\internship 2024\\data\\'

df_correct = pd.read_csv(path + "correct.csv") # read from csv FileExistsError
df_brokenV11 = pd.read_csv(path + "BrokenV11.csv") # read from csv FileExistsError
df_brokenH11 = pd.read_csv(path + "BrokenH11.csv") # read from csv FileExistsError

# %%
df_correct
# Out:
#    node1 node2   voltage1  voltage2
# 0    N00   N01  10.000000  7.307694
# 1    N00   N10  10.000000  7.307694
# 2    N01   N02   7.307694  5.769233
# 3    N01   N11   7.307694  6.153848
# 4    N02   N03   5.769233  5.000003
# 5    N02   N12   5.769233  5.000003
# 6    N03   N13   5.000003  4.230772
# 7    N10   N11   7.307694  6.153848
# 8    N10   N20   7.307694  5.769233
# 9    N11   N12   6.153848  5.000003
# 10   N11   N21   6.153848  5.000003
# 11   N12   N13   5.000003  4.230772
# 12   N12   N22   5.000003  3.846157
# 13   N13   N23   4.230772  2.692312
# 14   N20   N21   5.769233  5.000003
# 15   N20   N30   5.769233  5.000003
# 16   N21   N22   5.000003  3.846157
# 17   N21   N31   5.000003  4.230772
# 18   N22   N23   3.846157  2.692312
# 19   N22   N32   3.846157  2.692312
# 20   N23   N33   2.692312  0.000005
# 21   N30   N31   5.000003  4.230772
# 22   N31   N32   4.230772  2.692312
# 23   N32   N33   2.692312  0.000005

# %%
df_brokenV11
# Out:
#    node1 node2   voltage1  voltage2
# 0    N00   N01  10.000000  7.100398
# 1    N00   N10  10.000000  7.258918
# 2    N01   N02   7.100398  5.627480
# 3    N01   N11   7.100398  5.673715
# 4    N02   N03   5.627480  4.900928
# 5    N02   N12   5.627480  4.881113
# 6    N03   N13   4.900928  4.174376
# 7    N10   N11   7.258918  5.673715
# 8    N10   N20   7.258918  6.103040
# 9    N11   N12   5.673715  4.881113
# 10   N11   N21   5.673715  5.673713
# 11   N12   N13   4.881113  4.174376
# 12   N12   N22   4.881113  4.048880
# 13   N13   N23   4.174376  2.741087
# 14   N20   N21   6.103040  5.673713
# 15   N20   N30   6.103040  5.376488
# 16   N21   N22   5.673713  4.048880
# 17   N21   N31   5.673713  4.649936
# 18   N22   N23   4.048880  2.741087
# 19   N22   N32   4.048880  2.899607
# 20   N23   N33   2.741087  0.000006
# 21   N30   N31   5.376488  4.649936
# 22   N31   N32   4.649936  2.899607
# 23   N32   N33   2.899607  0.000006

# %%
df_brokenH11
# Out:
#    node1 node2   voltage1  voltage2
# 0    N00   N01  10.000000  7.258918
# 1    N00   N10  10.000000  7.100398
# 2    N01   N02   7.258918  6.103040
# 3    N01   N11   7.258918  5.673715
# 4    N02   N03   6.103040  5.376488
# 5    N02   N12   6.103040  5.673713
# 6    N03   N13   5.376488  4.649936
# 7    N10   N11   7.100398  5.673715
# 8    N10   N20   7.100398  5.627480
# 9    N11   N12   5.673715  5.673713
# 10   N11   N21   5.673715  4.881113
# 11   N12   N13   5.673713  4.649936
# 12   N12   N22   5.673713  4.048880
# 13   N13   N23   4.649936  2.899607
# 14   N20   N21   5.627480  4.881113
# 15   N20   N30   5.627480  4.900928
# 16   N21   N22   4.881113  4.048880
# 17   N21   N31   4.881113  4.174376
# 18   N22   N23   4.048880  2.899607
# 19   N22   N32   4.048880  2.741087
# 20   N23   N33   2.899607  0.000006
# 21   N30   N31   4.900928  4.174376
# 22   N31   N32   4.174376  2.741087
# 23   N32   N33   2.741087  0.000006

# %%
def change_df(df):
    df["voltage difference"] = df["voltage1"] - df["voltage2"]
    df = df.drop(columns=['voltage1', 'voltage2'])
    print(df)
    return df
df_correct = change_df(df_correct)
change_df(df_brokenV11)
change_df(df_brokenH11)
# Out:
#    node1 node2  voltage difference
# 0    N00   N01            2.692306
# 1    N00   N10            2.692306
# 2    N01   N02            1.538461
# 3    N01   N11            1.153846
# 4    N02   N03            0.769230
# 5    N02   N12            0.769230
# 6    N03   N13            0.769230
# 7    N10   N11            1.153846
# 8    N10   N20            1.538461
# 9    N11   N12            1.153846
# 10   N11   N21            1.153846
# 11   N12   N13            0.769230
# 12   N12   N22            1.153846
# 13   N13   N23            1.538461
# 14   N20   N21            0.769230
# 15   N20   N30            0.769230
# 16   N21   N22            1.153846
# 17   N21   N31            0.769230
# 18   N22   N23            1.153846
# 19   N22   N32            1.153846
# 20   N23   N33            2.692306
# 21   N30   N31            0.769230
# 22   N31   N32            1.538461
# 23   N32   N33            2.692306
#    node1 node2  voltage difference
# 0    N00   N01            2.899602
# ...

# %%
V11 = df_brokenV11['voltage difference']
H11 = df_brokenH11['voltage difference']

# %%
V11
# Out:
# 0     2.899602
# 1     2.741082
# 2     1.472919
# 3     1.426683
# 4     0.726552
# 5     0.746367
# 6     0.726552
# 7     1.585203
# 8     1.155879
# 9     0.792603
# 10    0.000002
# 11    0.706737
# 12    0.832233
# 13    1.433289
# 14    0.429327
# 15    0.726552
# 16    1.624833
# 17    1.023777
# 18    1.307793
# 19    1.149273
# 20    2.741082
# 21    0.726552
# 22    1.750329
# 23    2.899602
# Name: voltage difference, dtype: float64

# %%
H11
# Out:
# 0     2.741082
# 1     2.899602
# 2     1.155879
# 3     1.585203
# 4     0.726552
# 5     0.429327
# 6     0.726552
# 7     1.426683
# 8     1.472919
# 9     0.000002
# 10    0.792603
# 11    1.023777
# 12    1.624833
# 13    1.750329
# 14    0.746367
# 15    0.726552
# 16    0.832233
# 17    0.706737
# 18    1.149273
# 19    1.307793
# 20    2.899602
# 21    0.726552
# 22    1.433289
# 23    2.741082
# Name: voltage difference, dtype: float64

# %%
df_correct
# Out:
#    node1 node2  voltage difference
# 0    N00   N01            2.692306
# 1    N00   N10            2.692306
# 2    N01   N02            1.538461
# 3    N01   N11            1.153846
# 4    N02   N03            0.769230
# 5    N02   N12            0.769230
# 6    N03   N13            0.769230
# 7    N10   N11            1.153846
# 8    N10   N20            1.538461
# 9    N11   N12            1.153846
# 10   N11   N21            1.153846
# 11   N12   N13            0.769230
# 12   N12   N22            1.153846
# 13   N13   N23            1.538461
# 14   N20   N21            0.769230
# 15   N20   N30            0.769230
# 16   N21   N22            1.153846
# 17   N21   N31            0.769230
# 18   N22   N23            1.153846
# 19   N22   N32            1.153846
# 20   N23   N33            2.692306
# 21   N30   N31            0.769230
# 22   N31   N32            1.538461
# 23   N32   N33            2.692306

# %%
df = df_correct
df['broken V11'] = V11
df['broken H11'] = H11
df['letters'] = ''
df
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters
# 0    N00   N01            2.692306    2.899602    2.741082
# 1    N00   N10            2.692306    2.741082    2.899602
# 2    N01   N02            1.538461    1.472919    1.155879
# 3    N01   N11            1.153846    1.426683    1.585203
# 4    N02   N03            0.769230    0.726552    0.726552
# 5    N02   N12            0.769230    0.746367    0.429327
# 6    N03   N13            0.769230    0.726552    0.726552
# 7    N10   N11            1.153846    1.585203    1.426683
# 8    N10   N20            1.538461    1.155879    1.472919
# 9    N11   N12            1.153846    0.792603    0.000002
# 10   N11   N21            1.153846    0.000002    0.792603
# 11   N12   N13            0.769230    0.706737    1.023777
# 12   N12   N22            1.153846    0.832233    1.624833
# 13   N13   N23            1.538461    1.433289    1.750329
# 14   N20   N21            0.769230    0.429327    0.746367
# ...

# %%
n = 4
A = 65
def node_name(i, j):
    return f'N{i}{j}'

df['letters'] = ''

def adding_letters(column, ch, i, j):
    for ind in df.index:
        if(df[column][ind] == f'N{i}{j}'):
            c = df['letters'][ind]
            df.loc[ind, 'letters'] = c + ch

def giving_loc(i, j):
    adding_letters('node1', ch, i, j)
    adding_letters('node2', ch, i, j)
    
reverse = 0
for c in range(ord('A'), ord('A') + 4 * (n-1)):
    ch = chr(c)
    # print(ch, c - A)
    c = c - A
    # A B C
    # D E F
    # G H I
    # J K L
    '''
    Lets have 4 groups of letters
    '''
    if(int(c/3) == 0):
        giving_loc(0, c)
        # print(0, c)
    if(int(c/3) == 1):
        giving_loc(c - n + 1, 3)
        # print(c - n + 1, 3)
    if(int(c/3) == 2):
        giving_loc(3, c - n + 1 + reverse)
        # print(3, c - n + 1 + reverse)
        reverse -= 2
        # print(reverse)
    if(int(c/3) == 3):
        giving_loc(c + reverse, 0)
        # print(c + reverse, 0, c)
        reverse -= 2
        # print(reverse)
df2 = df
df
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters
# 0    N00   N01            2.692306    2.899602    2.741082      AB
# 1    N00   N10            2.692306    2.741082    2.899602      AL
# 2    N01   N02            1.538461    1.472919    1.155879      BC
# 3    N01   N11            1.153846    1.426683    1.585203       B
# 4    N02   N03            0.769230    0.726552    0.726552      CD
# 5    N02   N12            0.769230    0.746367    0.429327       C
# 6    N03   N13            0.769230    0.726552    0.726552      DE
# 7    N10   N11            1.153846    1.585203    1.426683       L
# 8    N10   N20            1.538461    1.155879    1.472919      KL
# 9    N11   N12            1.153846    0.792603    0.000002
# 10   N11   N21            1.153846    0.000002    0.792603
# 11   N12   N13            0.769230    0.706737    1.023777       E
# 12   N12   N22            1.153846    0.832233    1.624833
# ...

# %%
for ind in df.index:
    if(len(df['letters'][ind]) < 2):
        df = df.drop([ind]);
df
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters
# 0    N00   N01            2.692306    2.899602    2.741082      AB
# 1    N00   N10            2.692306    2.741082    2.899602      AL
# 2    N01   N02            1.538461    1.472919    1.155879      BC
# 4    N02   N03            0.769230    0.726552    0.726552      CD
# 6    N03   N13            0.769230    0.726552    0.726552      DE
# 8    N10   N20            1.538461    1.155879    1.472919      KL
# 13   N13   N23            1.538461    1.433289    1.750329      EF
# 15   N20   N30            0.769230    0.726552    0.726552      JK
# 20   N23   N33            2.692306    2.741082    2.899602      FG
# 21   N30   N31            0.769230    0.726552    0.726552      IJ
# 22   N31   N32            1.538461    1.750329    1.433289      HI
# 23   N32   N33            2.692306    2.899602    2.741082      GH

# %%
# # Save DataFrame to a excel file
df.to_csv(path+'perimeter.csv', index=False)

# # Optionally, display a message
print("Data saved to csv file.")
# Out:
# Data saved to csv file.

# %%
df1 = df
def swap_rows(df, row1, row2):
    df.iloc[row1], df.iloc[row2] =  df.iloc[row2].copy(), df.iloc[row1].copy()
    return df

df1 = swap_rows(df1, 1, 11)
df1 = swap_rows(df1, 2, 11)
df1 = swap_rows(df1, 3, 8)
df1 = swap_rows(df1, 4, 11)
df1 = swap_rows(df1, 7, 10)
# df1 = swap_rows(df1, 5, 6)
df1
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters
# 0    N00   N01            2.692306    2.899602    2.741082      AB
# 1    N32   N33            2.692306    2.899602    2.741082      GH
# 2    N00   N10            2.692306    2.741082    2.899602      AL
# 4    N23   N33            2.692306    2.741082    2.899602      FG
# 6    N01   N02            1.538461    1.472919    1.155879      BC
# 8    N10   N20            1.538461    1.155879    1.472919      KL
# 13   N13   N23            1.538461    1.433289    1.750329      EF
# 15   N31   N32            1.538461    1.750329    1.433289      HI
# 20   N02   N03            0.769230    0.726552    0.726552      CD
# 21   N30   N31            0.769230    0.726552    0.726552      IJ
# 22   N20   N30            0.769230    0.726552    0.726552      JK
# 23   N03   N13            0.769230    0.726552    0.726552      DE

# %% [markdown]
# Green - Correct
#
# Blue - V11 broken
#
# Red - H11 broken
#
# Let's look at the green dots. We can see that AB and GH are symetrical.
# other symteries: AL and FG. BC, KL, EF, HI. CD, DE, JK, IJ.
#
# After V11 is broken, all the values change but AB and GH stay symetrical. as well as AL and FG. and CD, DE, JK, IJ. Only ones that arent symetrical are BC, KL, EF, HI which are middle resistances in the perimeter.
#
# BC decreases
#
# HI increases
#
# EF decreases
#
# KL decreases
#
# After H11 is broken, the same symetries stay as when V11 was broken.
#
# BC decreases
#
# HI decreases
#
# EF increases
#
# KL decreases

# %%
import matplotlib.pyplot as plt

df = df1
names = df['letters']
correct = df['voltage difference']
broken_V11 = df['broken V11']
broken_H11 = df['broken H11']

fig, ax = plt.subplots()
ax.scatter(names, correct, color = "green")
ax.scatter(names, broken_V11, color = 'blue')
# ax.scatter(names, broken_H11, color = 'red')
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %% [raw]
# When a resistor is broken the near paralel resistor will decrease drasticly and farthest will decrease a little bit.
# sides which arent parallel: one near source/gnd will decrease slightly(i mean the brokenresistor itself is near the souce/gnd and I mean near side other resistor, you know what I mean.....), another will increase.
#
# corners where voltage source and ground are not will decrease slightly.
# Now other corners: parallel to resitor will increase a bit, another one will increase not drasticly but well.

# %%
for ind in df.index:
    print(df['letters'][ind], df['broken V11'][ind] - df['voltage difference'][ind])
# Out:
# AB 0.2072954220401968
# GH 0.20729542182295768
# AL 0.04877534080300183
# FG 0.04877534058576227
# BC -0.06554199605043642
# KL -0.3825821585248246
# EF -0.10517201641404439
# HI 0.21186814606034332
# CD -0.04267850311612076
# IJ -0.04267850311612076
# JK -0.04267850311611987
# DE -0.04267850311611987

# %% [raw]
# PREDICTION!!!
#
# for V12:
# AB 0.2072954220401968
# GH 0.20729542182295768
# AL 0.04877534080300183
# FG 0.04877534058576227
# BC 0.21186814606034332
# KL -0.10517201641404439
# EF -0.3825821585248246
# HI -0.06554199605043642
# CD -0.04267850311612076
# IJ -0.04267850311612076
# JK -0.04267850311611987
# DE -0.04267850311611987
#
# for H12:
# AB 0.04877534080300183
# GH 0.04877534080300183
# AL 0.20729542182295768
# FG 0.2072954220401968
# BC -0.10517201641404439
# KL 0.21186814606034332
# EF -0.06554199605043642
# HI -0.3825821585248246
# CD -0.04267850311612076
# IJ -0.04267850311612076
# JK -0.04267850311611987
# DE -0.04267850311611987

# %% [raw]
# Before I check for the prediction I want to find formula which will prove my predictions. So im gonna start new jupyter file to test stuff there

# %% [raw]
# Something new!!! after checking some stuff in 'making formula' file, now I'm back here to try some stuff out.

# %%
df['V11'] = (df['broken V11'] - df['voltage difference'])
df['H11'] = (df['broken H11'] - df['voltage difference'])
df
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters       V11  \
# 0    N00   N01            2.692306    2.899602    2.741082      AB  0.207295
# 1    N32   N33            2.692306    2.899602    2.741082      GH  0.207295
# 2    N00   N10            2.692306    2.741082    2.899602      AL  0.048775
# 4    N23   N33            2.692306    2.741082    2.899602      FG  0.048775
# 6    N01   N02            1.538461    1.472919    1.155879      BC -0.065542
# 8    N10   N20            1.538461    1.155879    1.472919      KL -0.382582
# 13   N13   N23            1.538461    1.433289    1.750329      EF -0.105172
# 15   N31   N32            1.538461    1.750329    1.433289      HI  0.211868
# 20   N02   N03            0.769230    0.726552    0.726552      CD -0.042679
# 21   N30   N31            0.769230    0.726552    0.726552      IJ -0.042679
# 22   N20   N30            0.769230    0.726552    0.726552      JK -0.042679
# ...

# %%
df2
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters
# 0    N00   N01            2.692306    2.899602    2.741082      AB
# 1    N00   N10            2.692306    2.741082    2.899602      AL
# 2    N01   N02            1.538461    1.472919    1.155879      BC
# 3    N01   N11            1.153846    1.426683    1.585203       B
# 4    N02   N03            0.769230    0.726552    0.726552      CD
# 5    N02   N12            0.769230    0.746367    0.429327       C
# 6    N03   N13            0.769230    0.726552    0.726552      DE
# 7    N10   N11            1.153846    1.585203    1.426683       L
# 8    N10   N20            1.538461    1.155879    1.472919      KL
# 9    N11   N12            1.153846    0.792603    0.000002
# 10   N11   N21            1.153846    0.000002    0.792603
# 11   N12   N13            0.769230    0.706737    1.023777       E
# 12   N12   N22            1.153846    0.832233    1.624833
# ...

# %%
for ind in df2.index:
    if(len(df2['letters'][ind]) == 2):
        df2 = df2.drop([ind]);
df2
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters
# 3    N01   N11            1.153846    1.426683    1.585203       B
# 5    N02   N12            0.769230    0.746367    0.429327       C
# 7    N10   N11            1.153846    1.585203    1.426683       L
# 9    N11   N12            1.153846    0.792603    0.000002
# 10   N11   N21            1.153846    0.000002    0.792603
# 11   N12   N13            0.769230    0.706737    1.023777       E
# 12   N12   N22            1.153846    0.832233    1.624833
# 14   N20   N21            0.769230    0.429327    0.746367       K
# 16   N21   N22            1.153846    1.624833    0.832233
# 17   N21   N31            0.769230    1.023777    0.706737       I
# 18   N22   N23            1.153846    1.307793    1.149273       F
# 19   N22   N32            1.153846    1.149273    1.307793       H

# %%
def adding_letters2(column, ch, i, j):
    for ind in df2.index:
        if(df2[column][ind] == f'N{i}{j}'):
            c = df2['letters'][ind]
            # print(i, j, ch, c)
            df2.loc[ind, 'letters'] = c + ch
adding_letters2('node1', '1', 1, 1)
adding_letters2('node2', '1', 1, 1)
adding_letters2('node1', '2', 1, 2)
adding_letters2('node2', '2', 1, 2)
adding_letters2('node1', '3', 2, 1)
adding_letters2('node2', '3', 2, 1)
adding_letters2('node1', '4', 2, 2)
adding_letters2('node2', '4', 2, 2)
df2
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters
# 3    N01   N11            1.153846    1.426683    1.585203      B1
# 5    N02   N12            0.769230    0.746367    0.429327      C2
# 7    N10   N11            1.153846    1.585203    1.426683      L1
# 9    N11   N12            1.153846    0.792603    0.000002      12
# 10   N11   N21            1.153846    0.000002    0.792603      13
# 11   N12   N13            0.769230    0.706737    1.023777      E2
# 12   N12   N22            1.153846    0.832233    1.624833      24
# 14   N20   N21            0.769230    0.429327    0.746367      K3
# 16   N21   N22            1.153846    1.624833    0.832233      34
# 17   N21   N31            0.769230    1.023777    0.706737      I3
# 18   N22   N23            1.153846    1.307793    1.149273      F4
# 19   N22   N32            1.153846    1.149273    1.307793      H4

# %%
df2['V11'] = (df2['broken V11'] - df2['voltage difference'])
df2
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters       V11
# 3    N01   N11            1.153846    1.426683    1.585203      B1  0.272837
# 5    N02   N12            0.769230    0.746367    0.429327      C2 -0.022863
# 7    N10   N11            1.153846    1.585203    1.426683      L1  0.431357
# 9    N11   N12            1.153846    0.792603    0.000002      12 -0.361243
# 10   N11   N21            1.153846    0.000002    0.792603      13 -1.153843
# 11   N12   N13            0.769230    0.706737    1.023777      E2 -0.062494
# 12   N12   N22            1.153846    0.832233    1.624833      24 -0.321613
# 14   N20   N21            0.769230    0.429327    0.746367      K3 -0.339904
# 16   N21   N22            1.153846    1.624833    0.832233      34  0.470988
# 17   N21   N31            0.769230    1.023777    0.706737      I3  0.254547
# 18   N22   N23            1.153846    1.307793    1.149273      F4  0.153947
# ...

# %%
df2 = df2.sort_values(by='V11', ascending=False, axis=0)
df2
# Out:
#    node1 node2  voltage difference  broken V11  broken H11 letters       V11
# 16   N21   N22            1.153846    1.624833    0.832233      34  0.470988
# 7    N10   N11            1.153846    1.585203    1.426683      L1  0.431357
# 3    N01   N11            1.153846    1.426683    1.585203      B1  0.272837
# 17   N21   N31            0.769230    1.023777    0.706737      I3  0.254547
# 18   N22   N23            1.153846    1.307793    1.149273      F4  0.153947
# 19   N22   N32            1.153846    1.149273    1.307793      H4 -0.004573
# 5    N02   N12            0.769230    0.746367    0.429327      C2 -0.022863
# 11   N12   N13            0.769230    0.706737    1.023777      E2 -0.062494
# 12   N12   N22            1.153846    0.832233    1.624833      24 -0.321613
# 14   N20   N21            0.769230    0.429327    0.746367      K3 -0.339904
# 9    N11   N12            1.153846    0.792603    0.000002      12 -0.361243
# ...

# %% [raw]
# I am leaving things like this for a while and Im gonna come back to it.
